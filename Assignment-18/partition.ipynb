# %%
from pyspark.sql import  SparkSession
from pyspark.sql.functions import col, desc, sum,avg
spark = SparkSession.builder.appName("SparkPractice").getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/14 05:33:29 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df.take(10)
# Out:
# [Row(id=0, value=0),
#  Row(id=1, value=1),
#  Row(id=2, value=2),
#  Row(id=3, value=3),
#  Row(id=4, value=4),
#  Row(id=5, value=5),
#  Row(id=6, value=6),
#  Row(id=7, value=7),
#  Row(id=8, value=8),
#  Row(id=9, value=9)]
# 26/06/14 05:33:42 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
print("Before Partition:" , df.rdd.getNumPartitions())
df.write.mode("overwrite").csv("output/BeforeEmp" , header = True)
# Out:
# Before Partition: 2

# %%
df_repartition=df.repartition(12)
print("After Partition:", df_repartition.rdd.getNumPartitions())
# Out:
# [Stage 2:>                                                          (0 + 2) / 2]
# After Partition: 12

# %%
df_repartition.write.mode("overwrite").csv("output/afterEmp" , header = True)

# %%
df_coal = df_repartition.coalesce(3)
print("After coalesced:" , df_coal.rdd.getNumPartitions())
# Out:
# [Stage 6:>                                                          (0 + 2) / 2]
# After coalesced: 3
# [Stage 6:=============================>                             (1 + 1) / 2]
